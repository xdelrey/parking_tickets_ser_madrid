# %%
import pandas as pd

# %%
df_1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/sample_trim_1.csv', sep=",")

# %%
df_2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/sample_trim_2.csv', sep=",")

# %%
df_3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/sample_trim_3.csv', sep=",")

# %%
df_4 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/sample_trim_4.csv', sep=",")

# %%
df_4.head()
# Out:
#   matricula_parquimetro      fecha_operacion         fecha_inicio  \
# 0               TELPARK  2024-12-17 13:41:49  2024-12-17 13:41:49
# 1             703530021  2024-10-28 15:35:07  2024-10-28 15:35:07
# 2              EASYPARK  2024-12-27 08:33:36  2024-12-27 09:00:00
# 3               TELPARK  2024-12-02 18:42:18  2024-12-02 18:42:18
# 4              EASYPARK  2024-12-14 14:20:54  2024-12-14 14:20:00
#
#              fecha_fin  cod_distrito   distrito  cod_barrio  \
# 0  2024-12-17 14:24:49             5  CHAMARTIN           1
# 1  2024-10-28 17:35:07             3     RETIRO           5
# 2  2024-12-27 09:43:00             1     CENTRO           3
# 3  2024-12-03 09:25:18             9    MONCLOA           3
# 4  2024-12-14 14:59:00             6     TETUAN           4
#
#                  barrio tipo_zona distintivo  minutos_tique importe_tique
# 0               EL VISO     VERDE          C             43          1,25
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_parquimetro  12000 non-null  object
#  1   fecha_operacion        12000 non-null  object
#  2   fecha_inicio           12000 non-null  object
#  3   fecha_fin              12000 non-null  object
#  4   cod_distrito           12000 non-null  int64
#  5   distrito               11991 non-null  object
#  6   cod_barrio             12000 non-null  int64
#  7   barrio                 12000 non-null  object
#  8   tipo_zona              12000 non-null  object
#  9   distintivo             12000 non-null  object
#  10  minutos_tique          12000 non-null  int64
#  11  importe_tique          12000 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.1+ MB

# %%
df = pd.concat([df_1, df_2], ignore_index=True)
df = pd.concat([df, df_3], ignore_index=True)
df = pd.concat([df, df_4], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44000 entries, 0 to 43999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_parquimetro  44000 non-null  object
#  1   fecha_operacion        44000 non-null  object
#  2   fecha_inicio           44000 non-null  object
#  3   fecha_fin              44000 non-null  object
#  4   cod_distrito           44000 non-null  int64
#  5   distrito               43649 non-null  object
#  6   cod_barrio             44000 non-null  int64
#  7   barrio                 44000 non-null  object
#  8   tipo_zona              44000 non-null  object
#  9   distintivo             44000 non-null  object
#  10  minutos_tique          44000 non-null  int64
#  11  importe_tique          44000 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 4.0+ MB

# %%
df.head()
# Out:
#   matricula_parquimetro      fecha_operacion         fecha_inicio  \
# 0             ELPARKING  2024-01-13 12:45:10  2024-01-13 12:45:10
# 1               TELPARK  2024-03-18 14:40:12  2024-03-18 14:40:12
# 2              EASYPARK  2024-02-27 12:00:12  2024-02-27 12:00:00
# 3             702430001  2024-03-18 16:45:04  2024-03-18 16:44:00
# 4              EASYPARK  2024-02-01 15:29:41  2024-02-01 15:29:00
#
#              fecha_fin  cod_distrito    distrito  cod_barrio  \
# 0  2024-01-13 13:50:10             2  ARGANZUELA           2
# 1  2024-03-18 16:41:12             4   SALAMANCA           2
# 2  2024-02-27 12:20:00             6      TETUAN           4
# 3  2024-03-18 17:48:00             2  ARGANZUELA           4
# 4  2024-02-01 15:45:00             9     MONCLOA           3
#
#                  barrio tipo_zona distintivo  minutos_tique importe_tique
# 0               ACACIAS      AZUL        ECO             65          0,30
# ...

# %%
df.to_csv('2024.csv', index=False)
