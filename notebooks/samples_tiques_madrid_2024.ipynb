# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/tercertrimestre2024.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7907706 entries, 0 to 7907705
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   matricula_parquimetro  object
#  1   fecha_operacion        object
#  2   fecha_inicio           object
#  3   fecha_fin              object
#  4   cod_distrito           int64
#  5   distrito               object
#  6   cod_barrio             int64
#  7   barrio                 object
#  8   tipo_zona              object
#  9   distintivo             object
#  10  minutos_tique          int64
#  11  importe_tique          object
# dtypes: int64(3), object(9)
# memory usage: 724.0+ MB

# %%
df.describe()
# Out:
#        cod_distrito    cod_barrio  minutos_tique
# count  7.907706e+06  7.907706e+06   7.907706e+06
# mean   5.829376e+00  3.438928e+00   7.240902e+01
# std    3.360655e+00  1.741217e+00   7.367134e+01
# min    1.000000e+00  0.000000e+00   0.000000e+00
# 25%    4.000000e+00  2.000000e+00   2.800000e+01
# 50%    5.000000e+00  4.000000e+00   5.300000e+01
# 75%    7.000000e+00  5.000000e+00   9.300000e+01
# max    2.900000e+01  8.000000e+00   7.200000e+02

# %%
# df tiene 12Mill de registros, me quedo con 12.000 registros aleatorios
df_sample = df.sample(n=8_000,         # cuántas filas me quedo
                    random_state=42)    # semilla

# Guardar la muestra a disco
df_sample.to_csv("sample_trim_3.csv", index=False)

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8000 entries, 6992122 to 2823028
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_parquimetro  8000 non-null   object
#  1   fecha_operacion        8000 non-null   object
#  2   fecha_inicio           8000 non-null   object
#  3   fecha_fin              8000 non-null   object
#  4   cod_distrito           8000 non-null   int64
#  5   distrito               7953 non-null   object
#  6   cod_barrio             8000 non-null   int64
#  7   barrio                 8000 non-null   object
#  8   tipo_zona              8000 non-null   object
#  9   distintivo             8000 non-null   object
#  10  minutos_tique          8000 non-null   int64
#  11  importe_tique          8000 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 812.5+ KB

# %%
df_sample.describe()
# Out:
#        cod_distrito   cod_barrio  minutos_tique
# count   8000.000000  8000.000000    8000.000000
# mean       5.816000     3.435250      72.439500
# std        3.304998     1.754335      72.917096
# min        1.000000     1.000000       1.000000
# 25%        4.000000     2.000000      28.000000
# 50%        5.000000     4.000000      53.000000
# 75%        7.000000     5.000000      93.000000
# max       15.000000     8.000000     624.000000

# %%
df.head()
# Out:
#   matricula_parquimetro      fecha_operacion         fecha_inicio  \
# 0             704130018  2024-07-19 18:28:13  2024-07-19 18:28:13
# 1              EASYPARK  2024-07-18 08:53:31  2024-07-18 09:00:00
# 2              EASYPARK  2024-07-30 18:19:47  2024-07-30 18:19:00
# 3             704130065  2024-07-27 08:32:41  2024-07-27 09:00:00
# 4              EASYPARK  2024-07-31 19:37:52  2024-07-31 19:37:00
#
#              fecha_fin  cod_distrito   distrito  cod_barrio     barrio  \
# 0  2024-07-19 20:29:13             4  SALAMANCA           1  RECOLETOS
# 1  2024-07-18 09:05:00             6     TETUAN           4   ALMENARA
# 2  2024-07-30 18:33:00             4  SALAMANCA           1  RECOLETOS
# 3  2024-07-27 11:39:00             4  SALAMANCA           1  RECOLETOS
# 4  2024-07-31 19:46:00             6     TETUAN           4   ALMENARA
#
#   tipo_zona distintivo  minutos_tique importe_tique
# 0      AZUL          C            121          2,50
# ...
